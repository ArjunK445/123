# %% [markdown]
# pandas assignment
#
# Write a Python program using Pandas to create a table that contains the following columns and data:
#
# Employee Name: John, Kate, Leo
#
# Department: IT, HR, Sales
#
# Salary: 50000, 55000, 60000
#
# Do this task from both Python Lists and Pythin DIctionary

# %%
import pandas as pd 
x ={"Employee Name" :["john"," kate" ,"Leo"],
    "Department":["IT","HR","Sales"],
    "Salary":[50000, 55000, 60000]}
data =pd.DataFrame(x,index=pd.RangeIndex(1,4,name='Index'))
print(f"data using dictionary: \n\n{data}\n")


y =[["john","IT",50000],["kate" ,"HR",55000],["Leo","Sales",60000]]
d = pd.DataFrame(y,columns=['Name','Dept','Sales'],index=pd.RangeIndex(1,4))

print(f"using list:\n\n{d}")
# Out:
# data using dictionary:
#
#       Employee Name Department  Salary
# Index
# 1              john         IT   50000
# 2              kate         HR   55000
# 3               Leo      Sales   60000
#
# using list:
#
#    Name   Dept  Sales
# 1  john     IT  50000
# 2  kate     HR  55000
# 3   Leo  Sales  60000
